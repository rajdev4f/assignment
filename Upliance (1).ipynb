# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
user_details = pd.read_csv('UserDetails.csv')
cooking_sessions = pd.read_csv('CookingSessions.csv')
order_details = pd.read_csv('OrderDetails.csv')
user_details
# Out:
#   User ID      User Name  Age       Location Registration Date         Phone  \
# 0    U001  Alice Johnson   28       New York        2023-01-15  123-456-7890
# 1    U002      Bob Smith   35    Los Angeles        2023-02-20  987-654-3210
# 2    U003    Charlie Lee   42        Chicago        2023-03-10  555-123-4567
# 3    U004    David Brown   27  San Francisco        2023-04-05  444-333-2222
# 4    U005     Emma White   30        Seattle        2023-05-22  777-888-9999
# 5    U006    Frank Green   25         Austin        2023-06-15  888-777-6666
# 6    U007     Grace King   38         Boston        2023-07-02  999-888-7777
# 7    U008      Henry Lee   31          Miami        2023-08-11  101-202-3030
# 8    U009    Irene Moore   33         Dallas        2023-09-01  202-303-4040
# 9    U010     Jack White   29        Phoenix        2023-10-10  303-404-5050
#
#                Email Favorite Meal  Total Orders
# 0    alice@email.com        Dinner            12
# 1      bob@email.com         Lunch             8
# 2  charlie@email.com     Breakfast            15
# 3    david@email.com        Dinner            10
# 4     emma@email.com         Lunch             9
# 5    frank@email.com        Dinner             7
# 6    grace@email.com     Breakfast            14
# 7    henry@email.com        Dinner             5
# 8    irene@email.com         Lunch             6
# 9     jack@email.com        Dinner             8

# %%
import csv as csv

# %%
cooking_sessions
# Out:
#    Session ID User ID        Dish Name  Meal Type     Session Start  \
# 0        S001    U001        Spaghetti     Dinner  2024-12-01 19:00
# 1        S002    U002     Caesar Salad      Lunch  2024-12-01 12:00
# 2        S003    U003  Grilled Chicken     Dinner  2024-12-02 19:30
# 3        S004    U001         Pancakes  Breakfast  2024-12-02 07:30
# 4        S005    U004     Caesar Salad      Lunch  2024-12-03 13:00
# 5        S006    U002        Spaghetti     Dinner  2024-12-03 18:30
# 6        S007    U005  Grilled Chicken     Dinner  2024-12-04 18:00
# 7        S008    U003    Veggie Burger      Lunch  2024-12-04 13:30
# 8        S009    U001  Grilled Chicken     Dinner  2024-12-05 19:00
# 9        S010    U002          Oatmeal  Breakfast  2024-12-05 07:00
# 10       S011    U003         Pancakes  Breakfast  2024-12-06 08:00
# 11       S012    U004        Spaghetti     Dinner  2024-12-06 19:00
# 12       S013    U005     Caesar Salad      Lunch  2024-12-07 12:30
# 13       S014    U006  Grilled Chicken     Dinner  2024-12-07 18:00
# 14       S015    U007        Spaghetti     Dinner  2024-12-08 19:30
# 15       S016    U008    Veggie Burger      Lunch  2024-12-08 13:30
#
#          Session End  Duration (mins)  Session Rating
# 0   2024-12-01 19:30               30             4.5
# 1   2024-12-01 12:20               20             4.0
# 2   2024-12-02 20:10               40             4.8
# 3   2024-12-02 08:00               30             4.2
# 4   2024-12-03 13:15               15             4.7
# 5   2024-12-03 19:00               30             4.3
# 6   2024-12-04 18:45               45             4.6
# 7   2024-12-04 13:50               20             4.4
# 8   2024-12-05 19:40               40             4.9
# 9   2024-12-05 07:10               10             4.1
# 10  2024-12-06 08:30               30             4.6
# 11  2024-12-06 19:40               40             4.7
# 12  2024-12-07 13:00               30             4.4
# 13  2024-12-07 18:45               45             4.8
# 14  2024-12-08 20:10               40             5.0
# 15  2024-12-08 13:50               20             4.3

# %%
order_details
# Out:
#     Order ID User ID  Order Date  Meal Type        Dish Name Order Status  \
# 0       1001    U001  2024-12-01     Dinner        Spaghetti    Completed
# 1       1002    U002  2024-12-01      Lunch     Caesar Salad    Completed
# 2       1003    U003  2024-12-02     Dinner  Grilled Chicken     Canceled
# 3       1004    U001  2024-12-02  Breakfast         Pancakes    Completed
# 4       1005    U004  2024-12-03      Lunch     Caesar Salad    Completed
# 5       1006    U002  2024-12-03     Dinner        Spaghetti    Completed
# 6       1007    U005  2024-12-04     Dinner  Grilled Chicken    Completed
# 7       1008    U003  2024-12-04      Lunch    Veggie Burger     Canceled
# 8       1009    U001  2024-12-05     Dinner  Grilled Chicken    Completed
# 9       1010    U002  2024-12-05  Breakfast          Oatmeal    Completed
# 10      1011    U003  2024-12-06  Breakfast         Pancakes    Completed
# 11      1012    U004  2024-12-06     Dinner        Spaghetti    Completed
# 12      1013    U005  2024-12-07      Lunch     Caesar Salad    Completed
# 13      1014    U006  2024-12-07     Dinner  Grilled Chicken    Completed
# 14      1015    U007  2024-12-08     Dinner        Spaghetti    Completed
# 15      1016    U008  2024-12-08      Lunch    Veggie Burger    Completed
#
#     Amount (USD) Time of Day  Rating Session ID
# 0           15.0       Night     5.0       S001
# 1           10.0         Day     4.0       S002
# 2           12.5       Night     NaN       S003
# 3            8.0     Morning     4.0       S004
# 4            9.0         Day     4.0       S005
# 5           14.0       Night     4.0       S006
# 6           13.5       Night     4.0       S007
# 7           11.0         Day     NaN       S008
# 8           12.0       Night     5.0       S009
# 9            7.0     Morning     4.0       S010
# 10           8.5     Morning     4.0       S011
# 11          12.5       Night     4.0       S012
# 12           9.0         Day     4.0       S013
# 13          13.0       Night     5.0       S014
# 14          14.0       Night     5.0       S015
# 15          11.0         Day     4.0       S016

# %%
user_details['Registration Date'] = pd.to_datetime(user_details['Registration Date'])
cooking_sessions['Session Start'] = pd.to_datetime(cooking_sessions['Session Start'])
cooking_sessions['Session End'] = pd.to_datetime(cooking_sessions['Session End'])
order_details['Order Date'] = pd.to_datetime(order_details['Order Date'])

# %%
order_details['Rating']=order_details['Rating'].fillna(0.0)
order_details
# Out:
#     Order ID User ID Order Date  Meal Type        Dish Name Order Status  \
# 0       1001    U001 2024-12-01     Dinner        Spaghetti    Completed
# 1       1002    U002 2024-12-01      Lunch     Caesar Salad    Completed
# 2       1003    U003 2024-12-02     Dinner  Grilled Chicken     Canceled
# 3       1004    U001 2024-12-02  Breakfast         Pancakes    Completed
# 4       1005    U004 2024-12-03      Lunch     Caesar Salad    Completed
# 5       1006    U002 2024-12-03     Dinner        Spaghetti    Completed
# 6       1007    U005 2024-12-04     Dinner  Grilled Chicken    Completed
# 7       1008    U003 2024-12-04      Lunch    Veggie Burger     Canceled
# 8       1009    U001 2024-12-05     Dinner  Grilled Chicken    Completed
# 9       1010    U002 2024-12-05  Breakfast          Oatmeal    Completed
# 10      1011    U003 2024-12-06  Breakfast         Pancakes    Completed
# 11      1012    U004 2024-12-06     Dinner        Spaghetti    Completed
# 12      1013    U005 2024-12-07      Lunch     Caesar Salad    Completed
# 13      1014    U006 2024-12-07     Dinner  Grilled Chicken    Completed
# 14      1015    U007 2024-12-08     Dinner        Spaghetti    Completed
# 15      1016    U008 2024-12-08      Lunch    Veggie Burger    Completed
#
#     Amount (USD) Time of Day  Rating Session ID
# 0           15.0       Night     5.0       S001
# 1           10.0         Day     4.0       S002
# 2           12.5       Night     0.0       S003
# 3            8.0     Morning     4.0       S004
# 4            9.0         Day     4.0       S005
# 5           14.0       Night     4.0       S006
# 6           13.5       Night     4.0       S007
# 7           11.0         Day     0.0       S008
# 8           12.0       Night     5.0       S009
# 9            7.0     Morning     4.0       S010
# 10           8.5     Morning     4.0       S011
# 11          12.5       Night     4.0       S012
# 12           9.0         Day     4.0       S013
# 13          13.0       Night     5.0       S014
# 14          14.0       Night     5.0       S015
# 15          11.0         Day     4.0       S016

# %%
merged_data = order_details.merge(cooking_sessions, on=['Session ID', 'User ID', 'Dish Name', 'Meal Type'], how='left')
merged_data = merged_data.merge(user_details, on='User ID', how='left')

mergeall3data=merged_data.merge(order_details,on='User ID',how='left')
merged_data
# Out:
#     Order ID User ID Order Date  Meal Type        Dish Name Order Status  \
# 0       1001    U001 2024-12-01     Dinner        Spaghetti    Completed
# 1       1002    U002 2024-12-01      Lunch     Caesar Salad    Completed
# 2       1003    U003 2024-12-02     Dinner  Grilled Chicken     Canceled
# 3       1004    U001 2024-12-02  Breakfast         Pancakes    Completed
# 4       1005    U004 2024-12-03      Lunch     Caesar Salad    Completed
# 5       1006    U002 2024-12-03     Dinner        Spaghetti    Completed
# 6       1007    U005 2024-12-04     Dinner  Grilled Chicken    Completed
# 7       1008    U003 2024-12-04      Lunch    Veggie Burger     Canceled
# 8       1009    U001 2024-12-05     Dinner  Grilled Chicken    Completed
# 9       1010    U002 2024-12-05  Breakfast          Oatmeal    Completed
# 10      1011    U003 2024-12-06  Breakfast         Pancakes    Completed
# 11      1012    U004 2024-12-06     Dinner        Spaghetti    Completed
# 12      1013    U005 2024-12-07      Lunch     Caesar Salad    Completed
# 13      1014    U006 2024-12-07     Dinner  Grilled Chicken    Completed
# 14      1015    U007 2024-12-08     Dinner        Spaghetti    Completed
# 15      1016    U008 2024-12-08      Lunch    Veggie Burger    Completed
#
#     Amount (USD) Time of Day  Rating Session ID  ... Duration (mins)  \
# 0           15.0       Night     5.0       S001  ...              30
# 1           10.0         Day     4.0       S002  ...              20
# 2           12.5       Night     0.0       S003  ...              40
# 3            8.0     Morning     4.0       S004  ...              30
# 4            9.0         Day     4.0       S005  ...              15
# 5           14.0       Night     4.0       S006  ...              30
# 6           13.5       Night     4.0       S007  ...              45
# 7           11.0         Day     0.0       S008  ...              20
# 8           12.0       Night     5.0       S009  ...              40
# 9            7.0     Morning     4.0       S010  ...              10
# 10           8.5     Morning     4.0       S011  ...              30
# 11          12.5       Night     4.0       S012  ...              40
# 12           9.0         Day     4.0       S013  ...              30
# 13          13.0       Night     5.0       S014  ...              45
# 14          14.0       Night     5.0       S015  ...              40
# 15          11.0         Day     4.0       S016  ...              20
#
#    Session Rating      User Name  Age       Location  Registration Date  \
# 0             4.5  Alice Johnson   28       New York         2023-01-15
# 1             4.0      Bob Smith   35    Los Angeles         2023-02-20
# 2             4.8    Charlie Lee   42        Chicago         2023-03-10
# 3             4.2  Alice Johnson   28       New York         2023-01-15
# 4             4.7    David Brown   27  San Francisco         2023-04-05
# 5             4.3      Bob Smith   35    Los Angeles         2023-02-20
# 6             4.6     Emma White   30        Seattle         2023-05-22
# 7             4.4    Charlie Lee   42        Chicago         2023-03-10
# 8             4.9  Alice Johnson   28       New York         2023-01-15
# 9             4.1      Bob Smith   35    Los Angeles         2023-02-20
# 10            4.6    Charlie Lee   42        Chicago         2023-03-10
# 11            4.7    David Brown   27  San Francisco         2023-04-05
# 12            4.4     Emma White   30        Seattle         2023-05-22
# 13            4.8    Frank Green   25         Austin         2023-06-15
# 14            5.0     Grace King   38         Boston         2023-07-02
# 15            4.3      Henry Lee   31          Miami         2023-08-11
#
#            Phone              Email Favorite Meal Total Orders
# 0   123-456-7890    alice@email.com        Dinner           12
# 1   987-654-3210      bob@email.com         Lunch            8
# 2   555-123-4567  charlie@email.com     Breakfast           15
# 3   123-456-7890    alice@email.com        Dinner           12
# 4   444-333-2222    david@email.com        Dinner           10
# 5   987-654-3210      bob@email.com         Lunch            8
# 6   777-888-9999     emma@email.com         Lunch            9
# 7   555-123-4567  charlie@email.com     Breakfast           15
# 8   123-456-7890    alice@email.com        Dinner           12
# 9   987-654-3210      bob@email.com         Lunch            8
# 10  555-123-4567  charlie@email.com     Breakfast           15
# 11  444-333-2222    david@email.com        Dinner           10
# 12  777-888-9999     emma@email.com         Lunch            9
# 13  888-777-6666    frank@email.com        Dinner            7
# 14  999-888-7777    grace@email.com     Breakfast           14
# 15  101-202-3030    henry@email.com        Dinner            5
#
# [16 rows x 22 columns]

# %%
mergeall3data
# Out:
#     Order ID_x User ID Order Date_x Meal Type_x      Dish Name_x  \
# 0         1001    U001   2024-12-01      Dinner        Spaghetti
# 1         1001    U001   2024-12-01      Dinner        Spaghetti
# 2         1001    U001   2024-12-01      Dinner        Spaghetti
# 3         1002    U002   2024-12-01       Lunch     Caesar Salad
# 4         1002    U002   2024-12-01       Lunch     Caesar Salad
# 5         1002    U002   2024-12-01       Lunch     Caesar Salad
# 6         1003    U003   2024-12-02      Dinner  Grilled Chicken
# 7         1003    U003   2024-12-02      Dinner  Grilled Chicken
# 8         1003    U003   2024-12-02      Dinner  Grilled Chicken
# 9         1004    U001   2024-12-02   Breakfast         Pancakes
# 10        1004    U001   2024-12-02   Breakfast         Pancakes
# 11        1004    U001   2024-12-02   Breakfast         Pancakes
# 12        1005    U004   2024-12-03       Lunch     Caesar Salad
# 13        1005    U004   2024-12-03       Lunch     Caesar Salad
# 14        1006    U002   2024-12-03      Dinner        Spaghetti
# 15        1006    U002   2024-12-03      Dinner        Spaghetti
# 16        1006    U002   2024-12-03      Dinner        Spaghetti
# 17        1007    U005   2024-12-04      Dinner  Grilled Chicken
# 18        1007    U005   2024-12-04      Dinner  Grilled Chicken
# 19        1008    U003   2024-12-04       Lunch    Veggie Burger
# 20        1008    U003   2024-12-04       Lunch    Veggie Burger
# 21        1008    U003   2024-12-04       Lunch    Veggie Burger
# 22        1009    U001   2024-12-05      Dinner  Grilled Chicken
# 23        1009    U001   2024-12-05      Dinner  Grilled Chicken
# 24        1009    U001   2024-12-05      Dinner  Grilled Chicken
# 25        1010    U002   2024-12-05   Breakfast          Oatmeal
# 26        1010    U002   2024-12-05   Breakfast          Oatmeal
# 27        1010    U002   2024-12-05   Breakfast          Oatmeal
# 28        1011    U003   2024-12-06   Breakfast         Pancakes
# 29        1011    U003   2024-12-06   Breakfast         Pancakes
# 30        1011    U003   2024-12-06   Breakfast         Pancakes
# 31        1012    U004   2024-12-06      Dinner        Spaghetti
# 32        1012    U004   2024-12-06      Dinner        Spaghetti
# 33        1013    U005   2024-12-07       Lunch     Caesar Salad
# 34        1013    U005   2024-12-07       Lunch     Caesar Salad
# 35        1014    U006   2024-12-07      Dinner  Grilled Chicken
# 36        1015    U007   2024-12-08      Dinner        Spaghetti
# 37        1016    U008   2024-12-08       Lunch    Veggie Burger
#
#    Order Status_x  Amount (USD)_x Time of Day_x  Rating_x Session ID_x  ...  \
# 0       Completed            15.0         Night       5.0         S001  ...
# 1       Completed            15.0         Night       5.0         S001  ...
# 2       Completed            15.0         Night       5.0         S001  ...
# 3       Completed            10.0           Day       4.0         S002  ...
# 4       Completed            10.0           Day       4.0         S002  ...
# 5       Completed            10.0           Day       4.0         S002  ...
# 6        Canceled            12.5         Night       0.0         S003  ...
# 7        Canceled            12.5         Night       0.0         S003  ...
# 8        Canceled            12.5         Night       0.0         S003  ...
# 9       Completed             8.0       Morning       4.0         S004  ...
# 10      Completed             8.0       Morning       4.0         S004  ...
# 11      Completed             8.0       Morning       4.0         S004  ...
# 12      Completed             9.0           Day       4.0         S005  ...
# 13      Completed             9.0           Day       4.0         S005  ...
# 14      Completed            14.0         Night       4.0         S006  ...
# 15      Completed            14.0         Night       4.0         S006  ...
# 16      Completed            14.0         Night       4.0         S006  ...
# 17      Completed            13.5         Night       4.0         S007  ...
# 18      Completed            13.5         Night       4.0         S007  ...
# 19       Canceled            11.0           Day       0.0         S008  ...
# 20       Canceled            11.0           Day       0.0         S008  ...
# 21       Canceled            11.0           Day       0.0         S008  ...
# 22      Completed            12.0         Night       5.0         S009  ...
# 23      Completed            12.0         Night       5.0         S009  ...
# 24      Completed            12.0         Night       5.0         S009  ...
# 25      Completed             7.0       Morning       4.0         S010  ...
# 26      Completed             7.0       Morning       4.0         S010  ...
# 27      Completed             7.0       Morning       4.0         S010  ...
# 28      Completed             8.5       Morning       4.0         S011  ...
# 29      Completed             8.5       Morning       4.0         S011  ...
# 30      Completed             8.5       Morning       4.0         S011  ...
# 31      Completed            12.5         Night       4.0         S012  ...
# 32      Completed            12.5         Night       4.0         S012  ...
# 33      Completed             9.0           Day       4.0         S013  ...
# 34      Completed             9.0           Day       4.0         S013  ...
# 35      Completed            13.0         Night       5.0         S014  ...
# 36      Completed            14.0         Night       5.0         S015  ...
# 37      Completed            11.0           Day       4.0         S016  ...
#
#    Total Orders Order ID_y  Order Date_y  Meal Type_y      Dish Name_y  \
# 0            12       1001    2024-12-01       Dinner        Spaghetti
# 1            12       1004    2024-12-02    Breakfast         Pancakes
# 2            12       1009    2024-12-05       Dinner  Grilled Chicken
# 3             8       1002    2024-12-01        Lunch     Caesar Salad
# 4             8       1006    2024-12-03       Dinner        Spaghetti
# 5             8       1010    2024-12-05    Breakfast          Oatmeal
# 6            15       1003    2024-12-02       Dinner  Grilled Chicken
# 7            15       1008    2024-12-04        Lunch    Veggie Burger
# 8            15       1011    2024-12-06    Breakfast         Pancakes
# 9            12       1001    2024-12-01       Dinner        Spaghetti
# 10           12       1004    2024-12-02    Breakfast         Pancakes
# 11           12       1009    2024-12-05       Dinner  Grilled Chicken
# 12           10       1005    2024-12-03        Lunch     Caesar Salad
# 13           10       1012    2024-12-06       Dinner        Spaghetti
# 14            8       1002    2024-12-01        Lunch     Caesar Salad
# 15            8       1006    2024-12-03       Dinner        Spaghetti
# 16            8       1010    2024-12-05    Breakfast          Oatmeal
# 17            9       1007    2024-12-04       Dinner  Grilled Chicken
# 18            9       1013    2024-12-07        Lunch     Caesar Salad
# 19           15       1003    2024-12-02       Dinner  Grilled Chicken
# 20           15       1008    2024-12-04        Lunch    Veggie Burger
# 21           15       1011    2024-12-06    Breakfast         Pancakes
# 22           12       1001    2024-12-01       Dinner        Spaghetti
# 23           12       1004    2024-12-02    Breakfast         Pancakes
# 24           12       1009    2024-12-05       Dinner  Grilled Chicken
# 25            8       1002    2024-12-01        Lunch     Caesar Salad
# 26            8       1006    2024-12-03       Dinner        Spaghetti
# 27            8       1010    2024-12-05    Breakfast          Oatmeal
# 28           15       1003    2024-12-02       Dinner  Grilled Chicken
# 29           15       1008    2024-12-04        Lunch    Veggie Burger
# 30           15       1011    2024-12-06    Breakfast         Pancakes
# 31           10       1005    2024-12-03        Lunch     Caesar Salad
# 32           10       1012    2024-12-06       Dinner        Spaghetti
# 33            9       1007    2024-12-04       Dinner  Grilled Chicken
# 34            9       1013    2024-12-07        Lunch     Caesar Salad
# 35            7       1014    2024-12-07       Dinner  Grilled Chicken
# 36           14       1015    2024-12-08       Dinner        Spaghetti
# 37            5       1016    2024-12-08        Lunch    Veggie Burger
#
#     Order Status_y Amount (USD)_y Time of Day_y Rating_y Session ID_y
# 0        Completed           15.0         Night      5.0         S001
# 1        Completed            8.0       Morning      4.0         S004
# 2        Completed           12.0         Night      5.0         S009
# 3        Completed           10.0           Day      4.0         S002
# 4        Completed           14.0         Night      4.0         S006
# 5        Completed            7.0       Morning      4.0         S010
# 6         Canceled           12.5         Night      0.0         S003
# 7         Canceled           11.0           Day      0.0         S008
# 8        Completed            8.5       Morning      4.0         S011
# 9        Completed           15.0         Night      5.0         S001
# 10       Completed            8.0       Morning      4.0         S004
# 11       Completed           12.0         Night      5.0         S009
# 12       Completed            9.0           Day      4.0         S005
# 13       Completed           12.5         Night      4.0         S012
# 14       Completed           10.0           Day      4.0         S002
# 15       Completed           14.0         Night      4.0         S006
# 16       Completed            7.0       Morning      4.0         S010
# 17       Completed           13.5         Night      4.0         S007
# 18       Completed            9.0           Day      4.0         S013
# 19        Canceled           12.5         Night      0.0         S003
# 20        Canceled           11.0           Day      0.0         S008
# 21       Completed            8.5       Morning      4.0         S011
# 22       Completed           15.0         Night      5.0         S001
# 23       Completed            8.0       Morning      4.0         S004
# 24       Completed           12.0         Night      5.0         S009
# 25       Completed           10.0           Day      4.0         S002
# 26       Completed           14.0         Night      4.0         S006
# 27       Completed            7.0       Morning      4.0         S010
# 28        Canceled           12.5         Night      0.0         S003
# 29        Canceled           11.0           Day      0.0         S008
# 30       Completed            8.5       Morning      4.0         S011
# 31       Completed            9.0           Day      4.0         S005
# 32       Completed           12.5         Night      4.0         S012
# 33       Completed           13.5         Night      4.0         S007
# 34       Completed            9.0           Day      4.0         S013
# 35       Completed           13.0         Night      5.0         S014
# 36       Completed           14.0         Night      5.0         S015
# 37       Completed           11.0           Day      4.0         S016
#
# [38 rows x 31 columns]

# %%
# relationship between cooking sessions and user orders
# Calculate the avg duration of cooking sessions for each dish
avg_duration_per_dish = merged_data.groupby('Dish Name')['Duration (mins)'].mean().reset_index()
avg_duration_per_dish
# Out:
#          Dish Name  Duration (mins)
# 0     Caesar Salad        21.666667
# 1  Grilled Chicken        42.500000
# 2          Oatmeal        10.000000
# 3         Pancakes        30.000000
# 4        Spaghetti        35.000000
# 5    Veggie Burger        20.000000

# %%
user_analysis = merged_data.groupby('User ID').agg({'Duration (mins)': 'sum','Total Orders': 'first'}).reset_index()
user_analysis
# Out:
#   User ID  Duration (mins)  Total Orders
# 0    U001              100            12
# 1    U002               60             8
# 2    U003               90            15
# 3    U004               55            10
# 4    U005               75             9
# 5    U006               45             7
# 6    U007               40            14
# 7    U008               20             5

# %%
# Identify popular dishes
popular_dishes = merged_data['Dish Name'].value_counts().reset_index()
popular_dishes.columns = ['Dish Name', 'Order Count']
popular_dishes.columns
# Out:
# Index(['Dish Name', 'Order Count'], dtype='object')

# %%
#demographic factors that influence user behavior
#avg number of orders per user by age group
user_details['Age Group'] = pd.cut(user_details['Age'], bins=[20, 30, 40, 50], labels=['20-30', '30-40', '40-50'])
avg_orders_per_age_group = user_details.groupby('Age Group')['Total Orders'].mean().reset_index()
avg_orders_per_age_group
# Out:
# <ipython-input-15-9923243b2313>:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_orders_per_age_group = user_details.groupby('Age Group')['Total Orders'].mean().reset_index()
#   Age Group  Total Orders
# 0     20-30          9.20
# 1     30-40          8.25
# 2     40-50         15.00

# %%
# Create visualizations to showcase key insights
plt.figure(figsize=(12, 6))
sns.barplot(x='Dish Name', y='Order Count', data=popular_dishes)
plt.title('Popular Dishes')
plt.xticks(rotation=45)
plt.show()
plt.figure(figsize=(12, 6))
sns.barplot(x='Dish Name', y='Duration (mins)', data=avg_duration_per_dish)
plt.title('Average Duration of Cooking Sessions per Dish')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(12, 6))
sns.barplot(x='Age Group', y='Total Orders', data=avg_orders_per_age_group)
plt.title('Average Number of Orders per User by Age Group')
plt.show()

# %%
user_details = pd.read_csv('UserDetails.csv')
user_details['Registration Date'] = pd.to_datetime(user_details['Registration Date'])
#avg number of orders per user by age group
user_details['Age Group'] = pd.cut(user_details['Age'], bins=[20, 30, 40, 50], labels=['20-30', '30-40', '40-50'])
avg_orders_per_age_group = user_details.groupby('Age Group')['Total Orders'].mean().reset_index()
#pie chart for average number of orders per user by age group
plt.figure(figsize=(8, 8))
plt.pie(avg_orders_per_age_group['Total Orders'], labels=avg_orders_per_age_group['Age Group'], autopct='%1.1f%%', startangle=140)
plt.title('Average Number of Orders per User by Age Group')
plt.show()
# Out:
# <ipython-input-42-b254ba11d9ff>:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_orders_per_age_group = user_details.groupby('Age Group')['Total Orders'].mean().reset_index()

# %%
order_details = pd.read_csv('OrderDetails.csv')
# Convert date columns to datetime
order_details['Order Date'] = pd.to_datetime(order_details['Order Date'])

plt.figure(figsize=(14, 8))
sns.histplot(data=order_details, x='Order Date', hue='Meal Type', multiple='dodge', bins=30, kde=False)
plt.title('Histogram of Meal Types on All Specific Dates')
plt.xlabel('Order Date')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
merged_data = pd.merge(cooking_sessions, user_details, on='User ID')
# Group by 'User ID' and calculate the total duration of cooking sessions and total orders
user_analysis = merged_data.groupby('User ID').agg({'Duration (mins)': 'sum','Total Orders': 'first'}).reset_index()
plt.figure(figsize=(12, 6))
colors = sns.color_palette('husl', len(user_analysis))
sns.barplot(x='User ID', y='Total Orders', data=user_analysis, palette=colors)
plt.title('Total Orders by User')
plt.xlabel('User ID')
plt.ylabel('Total Orders')
plt.show()
# Out:
# <ipython-input-41-77a5873d7e88>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='User ID', y='Total Orders', data=user_analysis, palette=colors)

# %%
user_details = pd.read_csv('UserDetails.csv')
favorite_meal_counts = user_details['Favorite Meal'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(favorite_meal_counts, labels=favorite_meal_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Count of Favorite Meal')
plt.show()

# %%
from os import read
report = """
Report Summary:
1-->Popular Dishes:
1)The most popular dishes are Spaghetti and Grilled Chicken each are having 4 orders.
2)Caesar Salad is also popular with 3 orders.

2-->Average Duration of Cooking Sessions:
1)Grilled Chicken has the longest average cooking session duration of 42.5 minutes.
2)Spaghetti has an average cooking session duration of 35 minutes.
3)Caesar Salad has the shortest average cooking session duration of 21.7 minutes.
4)pancake has an average cooking session duration of 35 minutes.

3-->Demographic Factors Influencing User Behavior:
1)Users aged 40-50 have the highest average number of orders.
2)Users aged 20-30 and 30-40 have a lower average number of orders compared to the 40-50 age group.

Business Recommendations:
1)Focus on promoting popular dishes like Spaghetti and Grilled Chicken to attract more customer.
2)Consider offering quick meal options like Caesar Salad to cater to users looking for shorter cooking sessions.
3)Target marketing efforts towards users aged 30-40, as they have the highest average number of orders.
"""
with open('report.txt', 'w') as f:
    f.write(report)
with open('report.txt','r') as f:
    print(f.read())
# Out:
# Report Summary:
# 1-->Popular Dishes:
# 1)The most popular dishes are Spaghetti and Grilled Chicken each are having 4 orders.
# 2)Caesar Salad is also popular with 3 orders.
#
# 2-->Average Duration of Cooking Sessions:
# 1)Grilled Chicken has the longest average cooking session duration of 42.5 minutes.
# 2)Spaghetti has an average cooking session duration of 35 minutes.
# 3)Caesar Salad has the shortest average cooking session duration of 21.7 minutes.
# 4)pancake has an average cooking session duration of 35 minutes.
#
# 3-->Demographic Factors Influencing User Behavior:
# 1)Users aged 40-50 have the highest average number of orders.
# 2)Users aged 20-30 and 30-40 have a lower average number of orders compared to the 40-50 age group.
#
# Business Recommendations:
# 1)Focus on promoting popular dishes like Spaghetti and Grilled Chicken to attract more customer.
# 2)Consider offering quick meal options like Caesar Salad to cater to users looking for shorter cooking sessions.
# 3)Target marketing efforts towards users aged 30-40, as they have the highest average number of orders.
